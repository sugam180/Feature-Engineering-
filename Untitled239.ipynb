# %% [markdown]
# <a href="https://colab.research.google.com/github/sugam180/Feature-Engineering-/blob/main/Untitled239.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv('/content/employee_performance_standardization.csv')

# %%
df.head()
# Out:
#    Employee_ID   Age  Experience_Years  Training_Score  Weekly_Work_Hours  \
# 0         1001  30.2              13.1            75.2               36.4
# 1         1002  36.4               9.8            78.7               43.5
# 2         1003  23.6               5.3            75.3               45.0
# 3         1004  43.4               5.2            77.5               45.1
# 4         1005  38.8               5.6            62.6               40.6
#
#    Performance_Score
# 0              66.96
# 1              66.95
# 2              58.56
# 3              62.60
# 4              54.35

# %%
df.shape
# Out:
# (500, 6)

# %%
df.isnull().sum()
# Out:
# Employee_ID          0
# Age                  0
# Experience_Years     0
# Training_Score       0
# Weekly_Work_Hours    0
# Performance_Score    0
# dtype: int64

# %%
x = df.iloc[:, 1:5]

y = df.iloc[:, -1]

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42
)

# %%
for column in x_train.columns:

    sns.displot(
        x_train[column],
        kde=True
    )

# %%
scaler = StandardScaler()

x_train_standardized = scaler.fit_transform(x_train)

x_test_standardized = scaler.transform(x_test)

# %%
x_train_standardized = pd.DataFrame(
    x_train_standardized,
    columns=x_train.columns
)

x_test_standardized = pd.DataFrame(
    x_test_standardized,
    columns=x_test.columns
)

# %%
x_train_standardized.head()
# Out:
#         Age  Experience_Years  Training_Score  Weekly_Work_Hours
# 0  0.293014         -0.772482       -1.166198           1.316079
# 1  0.308745          0.003492        0.832724           0.553037
# 2 -1.342927         -0.229300       -0.448636           0.665249
# 3  0.214363          0.934661        2.395984          -1.466780
# 4  0.308745         -0.268099        0.140789          -0.008023

# %%
for column in x_train_standardized.columns:

    sns.displot(
        x_train_standardized[column],
        kde=True
    )
