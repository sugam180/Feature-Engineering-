# %% [markdown]
# <a href="https://colab.research.google.com/github/sugam180/Feature-Engineering-/blob/main/Untitled242.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd



df = pd.read_csv("/content/student_missing_data_project.csv")

print("Original Dataset:")
print(df)



print("\nDataset Shape:")
print(df.shape)

print("\nDataset Information:")
print(df.info())




print("\nMissing Values:")
print(df.isnull().sum())


print("\nMissing Value Percentage:")

missing_percentage = df.isnull().mean() * 100

print(missing_percentage)






print("\nComplete Case Analysis:")
print(cca_df)

print("\nOriginal Shape:", df.shape)
print("After Complete Case Analysis:", cca_df.shape)




df_clean = df.copy()



print("\nMean Age:")
print(df_clean["Age"].mean())

df_clean["Age"] = df_clean["Age"].fillna(
    df_clean["Age"].mean()
)


`

print("\nMedian Monthly Income:")
print(df_clean["Monthly_Income"].median())

df_clean["Monthly_Income"] = df_clean["Monthly_Income"].fillna(
    df_clean["Monthly_Income"].median()
)




print("\nMode City:")
print(df_clean["City"].mode()[0])

df_clean["City"] = df_clean["City"].fillna(
    df_clean["City"].mode()[0]
)




df_clean["Hostel"] = df_clean["Hostel"].fillna(
    "Unknown"
)


df_clean["Attendance"] = df_clean["Attendance"].ffill()



df_clean["Previous_Score"] = df_clean["Previous_Score"].bfill()



df_clean = df_clean.dropna(
    subset=["Final_Score"]
)




print("\nMissing Values After Cleaning:")
print(df_clean.isnull().sum())



print("\nCleaned Dataset:")
print(df_clean)




df_clean.to_csv(
    "cleaned_student_data.csv",
    index=False
)

print("\nCleaned dataset saved successfully!")
# Out:
# Original Dataset:
#     Student_ID   Age  Study_Hours  Monthly_Income       City Hostel  \
# 0         1001  20.0          2.5         18000.0    Kolkata    Yes
# 1         1002  21.0          3.0         22000.0      Delhi     No
# 2         1003   NaN          4.0         25000.0    Kolkata    Yes
# 3         1004  22.0          2.0             NaN  Bangalore     No
# 4         1005  20.0          5.0         24000.0        NaN    Yes
# 5         1006  23.0          3.5         26000.0     Mumbai    NaN
# 6         1007  21.0          4.5         27000.0    Kolkata    Yes
# 7         1008  22.0          1.5         19000.0      Delhi     No
# 8         1009  20.0          3.0         23000.0    Kolkata    Yes
# 9         1010  24.0          6.0        120000.0  Bangalore    Yes
# 10        1011  23.0          2.5         28000.0     Mumbai     No
# 11        1012   NaN          4.0         30000.0    Kolkata    Yes
# ...
